# %%
# %matplotlib notebook
import pandas as pd

# %%
df = pd.read_csv('lnkd.csv', parse_dates=['Date'], index_col=['Date'])

# %%
df[['Close', 'Volume']].plot(subplots=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x121597790>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1236788e0>],
#       dtype=object)

# %%
from ipywidgets import interact

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
@interact(limit=6)
def plot_sin(limit):
    xs = np.linspace(-limit, limit, 100)
    ys = np.sin(xs)
    plt.plot(xs, ys, label=f'sin(x), {-limit} - {limit}')
    plt.show()
# Out:
# interactive(children=(IntSlider(value=6, description='limit', max=18, min=-6), Output()), _dom_classes=('widge…
