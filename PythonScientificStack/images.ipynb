# %%
import cv2

# %%
coffee = 'Exercise Files/Ch10/10_04/coffee.jpg'

# %%
img = cv2.imread(coffee)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (341, 512, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.imshow(img)

# %% [markdown]
# plt.imshow expects the color sequence to be RGB, but cv2 loads images as BGR.

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Edge detection

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
plt.imshow(gray, cmap=plt.cm.gray)

# %%
edges = cv2.Canny(gray, 200, 200)

# %%
plt.imshow(edges, cmap=plt.cm.gray)
